# %%
fun tareas-y-mensajeros (ensayo)
    m ← montículo-vacío
    cota-superior ← 70
    solución ← solución-vacía
    añadir-nodo (ensayo, m)
    mientras ¬vacío (m) hacer
        nodo ← extraer-raíz (m)
        si válido (nodo) entonces
            si coste (nodo) < cota-superior entonces
                solución ← nodo
                cota-superior ← coste (nodo)
            fsi
        si no { Nodo no es válido (solución) }
            si cota-inferior (nodo) ≥ cota-superior entonces
                devolver solución
            si no { cota-inferior (nodo) < cota-superior }
                para cada hijo en compleciones (nodo) hacer
                    si cota-inferior (hijo) < cota-superior entonces
                        añadir-nodo (hijo, m)
                    fsi
                    fpara
            fsi
        fsi
    fmientras
ffun

# %%
def añadir_nodo(grafo,m):

    for key in grafo.keys():
        if key not in m:
            return m[key] = grafo[key]

def valido(nodo):
    pass

def compleciones(nodo):
    pass

def coste(nodo):
    pass

def extraer_raíz(m):

    for key in m.keys():

# %%
grafo = {
    'a' : [11, 12, 18, 40],
    'b' : [14, 15, 13, 22],
    'c' : [11, 17, 19, 23],
    'd' : [17, 14, 20, 28]
}

# %%
def asignacion(grafo)
    m = dict()
    cota_inferior = 58
    cota_superior = 73
    solución = []
    añadir_nodo(grafo, m)
    while len(m) < len(grafo):
        nodo = extraer_raíz(m)
        if valido(nodo):
            if coste(nodo) < cota_superior:
                solución = nodo
                cota_superior = coste(nodo)

        elif not valido(nodo):
            if cota_inferior(nodo) >= cota_superior:
                return solución
            elif not (cota_inferior(nodo) < cota_superior):
                for hijo in compleciones(nodo):
                    if cota_inferior(hijo) < cota_superior:
                        añadir_nodo(hijo, m)
